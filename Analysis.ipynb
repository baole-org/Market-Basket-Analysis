# %% [markdown]
# # Import and EDA

# %%
#importing libraries

#data
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style="ticks")

#time manipulation
from datetime import datetime, timedelta

#display setting
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter("ignore")
pd.set_option('display.max_columns', 100)
from IPython.core.display import display, HTML

#plotly
import plotly
from plotly.subplots import make_subplots
import plotly.express as px
import plotly.graph_objs as go
import plotly.figure_factory as ff
import plotly.subplots as sp

#MBA
# !pip install mlxtend --upgrade --no-deps
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

#graph
import networkx as nx
# !pip install pyvis
from pyvis.network import Network

#KMeans
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

#others
import os

# %matplotlib inline
# Out:
# Requirement already satisfied: mlxtend in c:\programdata\anaconda3\lib\site-packages (0.19.0)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Error parsing requirements for googledrivedownloader: [Errno 2] No such file or directory: 'c:\\programdata\\anaconda3\\lib\\site-packages\\googledrivedownloader-0.4.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -okeh (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -andas (c:\programdata\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.
# Collecting pyvis
#   Downloading pyvis-0.1.9-py3-none-any.whl (23 kB)
# Requirement already satisfied: jinja2>=2.9.6 in c:\programdata\anaconda3\lib\site-packages (from pyvis) (2.11.3)
# Requirement already satisfied: ipython>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from pyvis) (7.31.1)
# Collecting jsonpickle>=1.4.1
#   Downloading jsonpickle-2.1.0-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: networkx>=1.11 in c:\programdata\anaconda3\lib\site-packages (from pyvis) (2.6.3)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (60.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.20)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (2.11.2)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9.6->pyvis) (1.1.1)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.5)
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-2.1.0 pyvis-0.1.9

# %%
df = pd.read_csv('online_retail_data.csv', encoding= 'unicode_escape')

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']).dt.date

# %% [markdown]
# # Helper functions

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %% [markdown]
# # Cleaning

# %%
mask = (~df['CustomerID'].isna())

# %%
df = df[mask]

# %%
df = df.drop_duplicates()

# %%
df = df.loc[df['StockCode'].str.match("\d{5}")]

# %%
customer_stockcode_date = df.groupby(['CustomerID','StockCode', 'InvoiceDate'])['Quantity'].sum().reset_index()

# %%
customer_stockcode_date = customer_stockcode_date[customer_stockcode_date['Quantity']>0]
customer_stockcode_date.head()
# Out:
#    CustomerID StockCode InvoiceDate  Quantity
# 1     12347.0     16008  2011-07-04        24
# 2     12347.0     17021  2011-09-06        36
# 3     12347.0     20665  2011-07-04         6
# 4     12347.0     20719  2011-01-26        10
# 5     12347.0     20719  2011-02-08        10

# %%
df = pd.merge(left=df,
              right=customer_stockcode_date[['CustomerID','StockCode','InvoiceDate']],
              how='inner',
              on = ['CustomerID','StockCode','InvoiceDate']
             )

# %%
#Product code dict
Products = df.drop_duplicates(subset='StockCode')[['StockCode','Description']]

Products = dict(zip(df['StockCode'], df['Description']))

# %% [markdown]
# # RFM Engineering

# %%
last_day = df['InvoiceDate'].max()

# %%
df['Sale'] = df['Quantity']*df['UnitPrice']

# %%
RFM_df = df.groupby('CustomerID').agg({'Sale':'sum', 'InvoiceNo':'nunique', 'InvoiceDate':'max', 'Country':'first'}).reset_index()

# %%
RFM_df = RFM_df.rename(columns={'Sale':'Monetary_Total', 'InvoiceNo':'Frequency', 'InvoiceDate':'LastPurchase'})

# %%
RFM_df['Recency'] = (RFM_df['LastPurchase'] - last_day).dt.days

# %%
RFM_df['Monetary_Average'] = RFM_df['Monetary_Total']/RFM_df['Frequency']

# %%
bin_labels = ['1', '2', '3', '4', '5']
RFM_df['Recency Score'] = pd.qcut(RFM_df['Recency'],
                              q=5,
                              labels=bin_labels)
RFM_df['Frequency Score'] = pd.qcut(RFM_df['Frequency'],
                             q=5,
                             labels=['2', '3', '4', '5'],
                             duplicates='drop')
RFM_df['Monetary Score'] = pd.qcut(RFM_df['Monetary_Average'],
                              q=5,
                              labels=bin_labels)

RFM_df['RFM_Score'] = RFM_df['Recency Score'].astype('str') + RFM_df['Frequency Score'].astype('str') + RFM_df['Monetary Score'].astype('str')

RFM_df = RFM_df.reindex(columns=['CustomerID','Monetary_Total','Recency','Frequency','Monetary_Average','LastPurchase',
                                 'Recency Score', 'Frequency Score','Monetary Score','RFM_Score', 'Country'
                                ])
RFM_df.head()
# Out:
#    CustomerID  Monetary_Total  Recency  Frequency  Monetary_Average  \
# 0     12347.0         4310.00      -40          7        615.714286
# 1     12348.0         1437.24      -76          4        359.310000
# 2     12349.0         1457.55      -19          1       1457.550000
# 3     12350.0          294.40     -311          1        294.400000
# 4     12352.0         1265.41      -73          6        210.901667
#
#   LastPurchase Recency Score Frequency Score Monetary Score RFM_Score  Country
# 0   2011-10-31             4               5              5       455  Iceland
# 1   2011-09-25             3               4              4       344  Finland
# 2   2011-11-21             4               2              5       425    Italy
# 3   2011-02-02             1               2              3       123   Norway
# 4   2011-09-28             3               4              2       342   Norway

# %%
# RFM Clustering

# # Segmentation

# RFM_df['Tier'] = 'Tier 4'
# RFM_df.loc[RFM_df['Monetary Score'].astype(int)>=3,'Tier'] = 'Tier 3'
# RFM_df.loc[RFM_df['Frequency Score'].astype(int)>=3,'Tier'] = 'Tier 2'
# RFM_df.loc[(RFM_df['Monetary Score'].astype(int)>=3)&(RFM_df['Frequency Score'].astype(int)>=4),'Tier'] = 'Tier 1'

# fig = px.scatter(RFM_df, x= 'Recency', y='Frequency', size='Monetary_Average', color='Tier', size_max=20)
# fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0)',
#                    'paper_bgcolor': 'rgba(0, 0, 0, 0)'
#                   })
# fig.show()

# fig = px.scatter(RFM_df, x= 'Monetary_Average', y='Frequency', size='Monetary_Total', color='Tier', size_max=20)
# fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0)',
#                    'paper_bgcolor': 'rgba(0, 0, 0, 0)'
#                   })
# fig.show()

# tiers = RFM_df.drop_duplicates(subset='Tier')[['CustomerID','Tier']]
# tiers = dict(zip(RFM_df['CustomerID'], RFM_df['Tier']))

# df['Tier'] = df['CustomerID'].map(tiers)

# %% [markdown]
# # K-Means clustering

# %%
# Perform K-means algorithm
norm = MinMaxScaler()
data = pd.DataFrame(norm.fit_transform(RFM_df[['Monetary_Average', 'Frequency']]), columns=['M_Scaled', 'F_Scaled'])

# %%
km_scores = []

for k in range(2, 11):
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(data)
    km_scores.append(-km.score(data))

# %%
fig = px.line(x= range(2,11), y=km_scores)
fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0)',
                   'paper_bgcolor': 'rgba(0, 0, 0, 0)'
                  })
fig.update_xaxes(title = 'Number of Clusters')
fig.update_yaxes(title = 'Clustering Score')
fig.show()

# %%
no_of_clusters = 5
model = KMeans(n_clusters=no_of_clusters, random_state=42)
cluster = pd.DataFrame(model.fit_predict(data)).astype('category')
cluster.columns = ['Cluster']
data = data.merge(cluster, left_index=True, right_index=True)
data = pd.concat([RFM_df,data], axis=1)
fig = px.scatter(data,
                 x='M_Scaled',
                 y='F_Scaled',
                 size = 'Monetary_Total',
                 color='Cluster')
fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0)',
                   'paper_bgcolor': 'rgba(0, 0, 0, 0)'
                  })
fig.show()

# %%
Clusters = data.drop_duplicates(subset='Cluster')[['CustomerID','Cluster']]
Clusters = dict(zip(data['CustomerID'], data['Cluster']))

# %%
df['Cluster'] = df['CustomerID'].map(Clusters)

# %%
data.to_csv('Clustering_result.csv', index=False)

# %%
# percentage of non-UK customers
# data[data['Country']!='United Kingdom'].groupby('Cluster')['Country'].size()/data['Cluster'].value_counts()
data[data['Country']!='United Kingdom'].groupby('Cluster')['Country'].size()
# Out:
# Cluster
# 0    299
# 1     91
# 2     12
# 3      1
# 4     15
# Name: Country, dtype: int64

# %% [markdown]
# # Market Basket

# %%
data['Cluster'].value_counts()
# Out:
# 0    3737
# 1     340
# 4     226
# 2      23
# 3       7
# Name: Cluster, dtype: int64

# %%
df['Cluster'].value_counts()
# Out:
# 0    231428
# 4     83329
# 1     41148
# 3     24750
# 2     10468
# Name: Cluster, dtype: int64

# %%
data = df.groupby(['Cluster', 'InvoiceNo'])['StockCode'].count().reset_index()
data = data[data['StockCode']>1]
# data.groupby('Cluster')['InvoiceNo'].count()
data.groupby('Cluster')['InvoiceNo'].nunique()
# Out:
# Cluster
# 0    10592
# 1     1137
# 2      210
# 3      837
# 4     4370
# Name: InvoiceNo, dtype: int64

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# Sale           float64
# Cluster          int64
# dtype: object

# %%
clusters = list(df['Cluster'].unique())

# %%
def MBA(df=df, min_support=0.04, min_lift=1.2, output_graph_name='MBA_graph.html', max_rule = None):
    print(f"***************************Cluster {cluster}***************************************")
    basket = (df.groupby(['InvoiceNo', 'StockCode'])['Quantity']
              .sum().unstack().reset_index().fillna(0)
              .set_index('InvoiceNo'))

    basket_sets = basket.applymap(encode_units)

    mask = basket_sets.sum(axis=1) > 1
    basket_sets = basket_sets[mask]

    frequent_itemsets = fpgrowth(
        basket_sets, min_support=min_support, use_colnames=True, max_len=2)
    rules = association_rules(
        frequent_itemsets, metric="lift", min_threshold=min_lift)
    # change product code to product name for readability
    rules['antecedents'] = rules['antecedents'].apply(lambda x: list(x)[0])
    rules['consequents'] = rules['consequents'].apply(lambda x: list(x)[0])
    rules['source'] = rules['antecedents'].map(Products)
    rules['target'] = rules['consequents'].map(Products)
    
    # write to csv
    filename = f'Cluster {cluster}.csv'
    rules.to_csv(filename)

    # prepare for graph visualisation
    rules_viz = rules.copy(deep=True)
    rules_viz['pair'] = rules_viz[['antecedents', 'consequents']].values.tolist()
    rules_viz['pair'] = rules_viz['pair'].apply(frozenset)
    rules_viz = rules_viz.drop_duplicates(subset='pair', keep='first')

    # for network graph
    rules_viz['value'] = rules_viz['lift']
    rules_viz['title'] = rules_viz['lift'].astype('str')
    if max_rule:
        rules_viz = rules_viz.sort_values(by = 'lift', ascending = False).head(max_rule)
    else:
        rules_viz = rules_viz.sort_values(by = 'lift', ascending = False)
    print(rules_viz.head())

    G = nx.from_pandas_edgelist(df=rules_viz,
                                source='source',
                                target='target',
                                edge_attr=['value','title']
                                )

    net = Network(height='700px', width='1000px', notebook=True)
    net.from_nx(G)
    net.show(output_graph_name)
    print("******************************************************************")

# %%
min_support_dict = {0: 0.03, 1:0.06, 2: 0.06, 3: 0.03, 4: 0.03}

for cluster in clusters:
    output_graph_name = f'result/Cluster {cluster}.html'
    MBA(df[df['Cluster'] == cluster], output_graph_name=output_graph_name,
        #         min_support=0.03,
        min_support=min_support_dict[cluster],
        min_lift=1,
        max_rule=100
        )
# Out:
# ***************************Cluster 4***************************************
#    antecedents consequents  antecedent support  consequent support   support  \
# 22       22699       22697            0.048070            0.037439  0.031431
# 2        82482      82494L            0.052461            0.053848  0.030968
# 0        22726       22727            0.062399            0.066790  0.042061
# 34       23202       23203            0.063092            0.078345  0.039057
# 8        22386       21931            0.071643            0.068408  0.031431
#
#     confidence       lift  leverage  conviction  \
# 22    0.653846  17.464150  0.029631    2.780731
# 2     0.590308  10.962508  0.028143    2.309425
# 0     0.674074  10.092452  0.037894    2.863258
# 34    0.619048   7.901531  0.034114    2.419344
# 8     0.438710   6.413165  0.026530    1.659733
#
#                                source                           target  \
# 22   ROSES REGENCY TEACUP AND SAUCER   GREEN REGENCY TEACUP AND SAUCER
# 2   WOODEN PICTURE FRAME WHITE FINISH      WOODEN FRAME ANTIQUE WHITE
# 0          ALARM CLOCK BAKELIKE GREEN        ALARM CLOCK BAKELIKE RED
# 34             JUMBO BAG VINTAGE LEAF         JUMBO BAG VINTAGE DOILY
# 8             JUMBO BAG PINK POLKADOT           JUMBO STORAGE BAG SUKI
#
#                pair      value               title
# 22   (22699, 22697)  17.464150  17.464150047483383
# 2   (82482, 82494L)  10.962508   10.96250779905844
# 0    (22726, 22727)  10.092452  10.092451621171344
# 34   (23202, 23203)   7.901531   7.901531113920495
# 8    (22386, 21931)   6.413165   6.413164777680908
# ******************************************************************
# ***************************Cluster 0***************************************
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, source, target, pair, value, title]
# Index: []
# ******************************************************************
# ***************************Cluster 3***************************************
#    antecedents consequents  antecedent support  consequent support   support  \
# 44       23266       23264            0.041162            0.041162  0.033898
# 46       23266       23263            0.041162            0.043584  0.030266
# 36       22698       22697            0.043584            0.055690  0.038741
# 38       22699       22698            0.054479            0.043584  0.037530
# 24       22699       22697            0.054479            0.055690  0.046005
#
#     confidence       lift  leverage  conviction  \
# 44    0.823529  20.006920  0.032204    5.433414
# 46    0.735294  16.870915  0.028472    3.613129
# 36    0.888889  15.961353  0.036314    8.498789
# 38    0.688889  15.806173  0.035156    3.074196
# 24    0.844444  15.163285  0.042971    6.070564
#
#                                  source                              target  \
# 44  SET OF 3 WOODEN STOCKING DECORATION  SET OF 3 WOODEN SLEIGH DECORATIONS
# 46  SET OF 3 WOODEN STOCKING DECORATION   SET OF 3 WOODEN HEART DECORATIONS
# 36       PINK REGENCY TEACUP AND SAUCER     GREEN REGENCY TEACUP AND SAUCER
# 38     ROSES REGENCY TEACUP AND SAUCER       PINK REGENCY TEACUP AND SAUCER
# 24     ROSES REGENCY TEACUP AND SAUCER      GREEN REGENCY TEACUP AND SAUCER
#
#               pair      value               title
# 44  (23266, 23264)  20.006920   20.00692041522491
# 46  (23266, 23263)  16.870915   16.87091503267974
# 36  (22698, 22697)  15.961353  15.961352657004833
# 38  (22699, 22698)  15.806173  15.806172839506177
# 24  (22699, 22697)  15.163285   15.16328502415459
# ******************************************************************
# ***************************Cluster 1***************************************
#    antecedents consequents  antecedent support  consequent support   support  \
# 16       22698       22697            0.070160            0.095027  0.064831
# 0        22726       22727            0.077265            0.094139  0.063055
# 18       22699       22698            0.104796            0.070160  0.063055
# 2        22728       22727            0.077265            0.094139  0.061279
# 6        22699       22697            0.104796            0.095027  0.081705
#
#     confidence      lift  leverage  conviction  \
# 16    0.924051  9.724122  0.058164   11.915483
# 0     0.816092  8.669052  0.055781    4.925622
# 18    0.601695  8.576057  0.055703    2.334492
# 2     0.793103  8.424854  0.054005    4.378330
# 6     0.779661  8.204657  0.071747    4.107187
#
#                               source                           target  \
# 16    PINK REGENCY TEACUP AND SAUCER  GREEN REGENCY TEACUP AND SAUCER
# 0         ALARM CLOCK BAKELIKE GREEN        ALARM CLOCK BAKELIKE RED
# 18  ROSES REGENCY TEACUP AND SAUCER    PINK REGENCY TEACUP AND SAUCER
# 2          ALARM CLOCK BAKELIKE PINK        ALARM CLOCK BAKELIKE RED
# 6   ROSES REGENCY TEACUP AND SAUCER   GREEN REGENCY TEACUP AND SAUCER
#
#               pair     value              title
# 16  (22698, 22697)  9.724122  9.724121613628297
# 0   (22726, 22727)  8.669052  8.669052266319671
# 18  (22699, 22698)  8.576057  8.576056640205966
# 2   (22728, 22727)  8.424854  8.424853610930384
# 6   (22699, 22697)  8.204657  8.204657056866782
# ******************************************************************
# ***************************Cluster 2***************************************
#     antecedents consequents  antecedent support  consequent support   support  \
# 870       21494      84596B            0.061905            0.061905  0.061905
# 814       22422       22107            0.061905            0.061905  0.061905
# 658       21990       21993            0.061905            0.061905  0.061905
# 698       21985       23221            0.061905            0.061905  0.061905
# 802       23265       22107            0.061905            0.061905  0.061905
#
#      confidence       lift  leverage  conviction  \
# 870         1.0  16.153846  0.058073         inf
# 814         1.0  16.153846  0.058073         inf
# 658         1.0  16.153846  0.058073         inf
# 698         1.0  16.153846  0.058073         inf
# 802         1.0  16.153846  0.058073         inf
#
#                                 source                              target  \
# 870     ROTATING LEAVES T-LIGHT HOLDER  SMALL DOLLY MIX DESIGN ORANGE BOWL
# 814                TOOTHPASTE TUBE PEN                  PIZZA PLATE IN BOX
# 658       MODERN FLORAL STATIONERY SET          FLORAL FOLK STATIONERY SET
# 698  PACK OF 12 HEARTS DESIGN TISSUES     REINDEER HEART DECORATION SILVER
# 802   SET OF 3 WOODEN TREE DECORATIONS                  PIZZA PLATE IN BOX
#
#                 pair      value               title
# 870  (21494, 84596B)  16.153846  16.153846153846153
# 814   (22422, 22107)  16.153846  16.153846153846153
# 658   (21990, 21993)  16.153846  16.153846153846153
# 698   (21985, 23221)  16.153846  16.153846153846153
# 802   (23265, 22107)  16.153846  16.153846153846153
# ******************************************************************

# %%
min_support_dict = {0: 0.02, 1:0.04, 2: 0.04, 3: 0.02, 4: 0.02}

for cluster in clusters:
    output_graph_name = f'result/Cluster {cluster}.html'
    MBA(df[df['Cluster'] == cluster], output_graph_name=output_graph_name,
        #         min_support=0.03,
        min_support=min_support_dict[cluster],
        min_lift=1,
        max_rule=100
        )
# Out:
# ***************************Cluster 4***************************************
#     antecedents consequents  antecedent support  consequent support   support  \
# 160       22698       22697            0.033511            0.037439  0.026346
# 222       23300       23301            0.036515            0.042755  0.028426
# 108       22699       22697            0.048070            0.037439  0.031431
# 162       22699       22698            0.048070            0.033511  0.027271
# 60        22910       22086            0.032355            0.040675  0.020106
#
#      confidence       lift  leverage  conviction  \
# 160    0.786207  20.999489  0.025092    4.502300
# 222    0.778481  18.208040  0.026865    4.321278
# 108    0.653846  17.464150  0.029631    2.780731
# 162    0.567308  16.929244  0.025660    2.233665
# 60     0.621429  15.277963  0.018790    2.534066
#
#                                  source                             target  \
# 160      PINK REGENCY TEACUP AND SAUCER    GREEN REGENCY TEACUP AND SAUCER
# 222  GARDENERS KNEELING PAD CUP OF TEA   GARDENERS KNEELING PAD KEEP CALM
# 108    ROSES REGENCY TEACUP AND SAUCER     GREEN REGENCY TEACUP AND SAUCER
# 162    ROSES REGENCY TEACUP AND SAUCER      PINK REGENCY TEACUP AND SAUCER
# 60    PAPER CHAIN KIT VINTAGE CHRISTMAS    PAPER CHAIN KIT 50'S CHRISTMAS
#
#                pair      value               title
# 160  (22698, 22697)  20.999489  20.999489144316733
# 222  (23300, 23301)  18.208040   18.20803968525487
# 108  (22699, 22697)  17.464150  17.464150047483383
# 162  (22699, 22698)  16.929244  16.929244031830237
# 60   (22910, 22086)  15.277963  15.277962662337663
# ******************************************************************
# ***************************Cluster 0***************************************
#    antecedents consequents  antecedent support  consequent support   support  \
# 44       22698       22697            0.025852            0.033239  0.021496
# 42       22578       22577            0.028883            0.030871  0.021023
# 40       22699       22697            0.036458            0.033239  0.024148
# 50       23300       23301            0.035038            0.042803  0.025000
# 0        22726       22727            0.036364            0.042045  0.024337
#
#     confidence       lift  leverage  conviction  \
# 44    0.831502  25.016123  0.020637    5.737519
# 42    0.727869  23.577592  0.020131    3.561256
# 40    0.662338  19.926740  0.022936    2.863101
# 50    0.713514  16.669696  0.023500    3.341159
# 0     0.669271  15.917793  0.022808    2.896492
#
#                                 source                               target  \
# 44      PINK REGENCY TEACUP AND SAUCER      GREEN REGENCY TEACUP AND SAUCER
# 42  WOODEN STAR CHRISTMAS SCANDINAVIAN  WOODEN HEART CHRISTMAS SCANDINAVIAN
# 40    ROSES REGENCY TEACUP AND SAUCER       GREEN REGENCY TEACUP AND SAUCER
# 50  GARDENERS KNEELING PAD CUP OF TEA     GARDENERS KNEELING PAD KEEP CALM
# 0           ALARM CLOCK BAKELIKE GREEN            ALARM CLOCK BAKELIKE RED
#
#               pair      value               title
# 44  (22698, 22697)  25.016123   25.01612347766194
# 42  (22578, 22577)  23.577592  23.577592275973046
# 40  (22699, 22697)  19.926740  19.926739926739923
# 50  (23300, 23301)  16.669696   16.66969624491749
# 0   (22726, 22727)  15.917793  15.917792792792794
# ******************************************************************
# ***************************Cluster 3***************************************
#     antecedents consequents  antecedent support  consequent support   support  \
# 322       23174       23175            0.027845            0.025424  0.023002
# 306       23171       23170            0.030266            0.035109  0.029056
# 222      84596B      84596F            0.031477            0.029056  0.024213
# 80        22578       22579            0.038741            0.026634  0.021792
# 338       23266       23264            0.041162            0.041162  0.033898
#
#      confidence       lift  leverage  conviction  \
# 322    0.826087  32.492754  0.022294    5.603814
# 306    0.960000  27.343448  0.027993   24.122276
# 222    0.769231  26.474359  0.023298    4.207425
# 80     0.562500  21.119318  0.020760    2.224836
# 338    0.823529  20.006920  0.032204    5.433414
#
#                                   source                              target  \
# 322             REGENCY SUGAR BOWL GREEN              REGENCY MILK JUG PINK
# 306             REGENCY TEA PLATE GREEN             REGENCY TEA PLATE ROSES
# 222   SMALL DOLLY MIX DESIGN ORANGE BOWL        SMALL MARSHMALLOWS PINK BOWL
# 80    WOODEN STAR CHRISTMAS SCANDINAVIAN  WOODEN TREE CHRISTMAS SCANDINAVIAN
# 338  SET OF 3 WOODEN STOCKING DECORATION  SET OF 3 WOODEN SLEIGH DECORATIONS
#
#                  pair      value               title
# 322    (23174, 23175)  32.492754  32.492753623188406
# 306    (23170, 23171)  27.343448  27.343448275862073
# 222  (84596B, 84596F)  26.474359   26.47435897435897
# 80     (22578, 22579)  21.119318  21.119318181818176
# 338    (23266, 23264)  20.006920   20.00692041522491
# ******************************************************************
# ***************************Cluster 1***************************************
#    antecedents consequents  antecedent support  consequent support   support  \
# 94       22698       22697            0.070160            0.095027  0.064831
# 80       22727       22729            0.094139            0.046181  0.040853
# 8        22910       22086            0.065719            0.076377  0.047069
# 12       22727       22730            0.094139            0.048845  0.042629
# 30       22728       22726            0.077265            0.077265  0.054174
#
#     confidence      lift  leverage  conviction  \
# 94    0.924051  9.724122  0.058164   11.915483
# 80    0.433962  9.396952  0.036505    1.685080
# 8     0.716216  9.377436  0.042050    3.254673
# 12    0.452830  9.270669  0.038031    1.738317
# 30    0.701149  9.074647  0.048204    3.087614
#
#                                source                           target  \
# 94     PINK REGENCY TEACUP AND SAUCER  GREEN REGENCY TEACUP AND SAUCER
# 80          ALARM CLOCK BAKELIKE RED       ALARM CLOCK BAKELIKE ORANGE
# 8   PAPER CHAIN KIT VINTAGE CHRISTMAS  PAPER CHAIN KIT 50'S CHRISTMAS
# 12          ALARM CLOCK BAKELIKE RED        ALARM CLOCK BAKELIKE IVORY
# 30          ALARM CLOCK BAKELIKE PINK       ALARM CLOCK BAKELIKE GREEN
#
#               pair     value              title
# 94  (22698, 22697)  9.724122  9.724121613628297
# 80  (22727, 22729)  9.396952  9.396952104499274
# 8   (22910, 22086)  9.377436  9.377435575109994
# 12  (22727, 22730)  9.270669   9.27066895368782
# 30  (22728, 22726)  9.074647  9.074646584753602
# ******************************************************************
# ***************************Cluster 2***************************************
#       antecedents consequents  antecedent support  consequent support  \
# 8588        23286       23285            0.042857            0.042857
# 8584        23288       23285            0.042857            0.042857
# 8586        23286       23288            0.042857            0.042857
# 26402       16238      85039B            0.047619            0.042857
# 25366       21790      85049A            0.047619            0.047619
#
#         support  confidence       lift  leverage  conviction  \
# 8588   0.042857         1.0  23.333333  0.041020         inf
# 8584   0.042857         1.0  23.333333  0.041020         inf
# 8586   0.042857         1.0  23.333333  0.041020         inf
# 26402  0.042857         0.9  21.000000  0.040816    9.571429
# 25366  0.047619         1.0  21.000000  0.045351         inf
#
#                           source                              target  \
# 8588    BLUE VINTAGE SPOT BEAKER            PINK VINTAGE SPOT BEAKER
# 8584   GREEN VINTAGE SPOT BEAKER            PINK VINTAGE SPOT BEAKER
# 8586    BLUE VINTAGE SPOT BEAKER           GREEN VINTAGE SPOT BEAKER
# 26402  PARTY TIME PENCIL ERASERS  S/4 IVORY MINI ROSE CANDLE IN BOWL
# 25366         VINTAGE SNAP CARDS       TRADITIONAL CHRISTMAS RIBBONS
#
#                   pair      value               title
# 8588    (23286, 23285)  23.333333  23.333333333333332
# 8584    (23288, 23285)  23.333333  23.333333333333332
# 8586    (23286, 23288)  23.333333  23.333333333333332
# 26402  (16238, 85039B)  21.000000                21.0
# 25366  (21790, 85049A)  21.000000                21.0
# ******************************************************************

# %% [markdown]
# # Import and EDA

# %%
#importing libraries

#data
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style="ticks")

#time manipulation
from datetime import datetime, timedelta

#display setting
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.simplefilter("ignore")
pd.set_option('display.max_columns', 100)
from IPython.core.display import display, HTML

#plotly
import plotly
from plotly.subplots import make_subplots
import plotly.express as px
import plotly.graph_objs as go
import plotly.figure_factory as ff
import plotly.subplots as sp

#MBA
# !pip install mlxtend --upgrade --no-deps
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

#graph
import networkx as nx
# !pip install pyvis
from pyvis.network import Network

#KMeans
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

#others
import os

# %matplotlib inline
# Out:
# Requirement already up-to-date: mlxtend in c:\users\mark.bao\anaconda3\lib\site-packages (0.18.0)
# Requirement already satisfied: pyvis in c:\users\mark.bao\anaconda3\lib\site-packages (0.1.9)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\mark.bao\anaconda3\lib\site-packages (from pyvis) (2.0.0)
# Requirement already satisfied: networkx>=1.11 in c:\users\mark.bao\anaconda3\lib\site-packages (from pyvis) (2.5)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\mark.bao\anaconda3\lib\site-packages (from pyvis) (2.11.2)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\mark.bao\anaconda3\lib\site-packages (from pyvis) (7.19.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\mark.bao\anaconda3\lib\site-packages (from networkx>=1.11->pyvis) (4.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mark.bao\anaconda3\lib\site-packages (from jinja2>=2.9.6->pyvis) (1.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mark.bao\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (50.3.1.post20201107)
# Requirement already satisfied: traitlets>=4.2 in c:\users\mark.bao\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (5.0.5)
# Requirement already satisfied: pygments in c:\users\mark.bao\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (2.7.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\mark.bao\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mark.bao\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.8)
# Requirement already satisfied: jedi>=0.10 in c:\users\mark.bao\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.17.1)
# Requirement already satisfied: backcall in c:\users\mark.bao\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\mark.bao\anaconda3\lib\site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: ipython-genutils in c:\users\mark.bao\anaconda3\lib\site-packages (from traitlets>=4.2->ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\mark.bao\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\mark.bao\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.3.0->pyvis) (0.7.0)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Assignment_2_data/online_retail_data.csv', encoding= 'unicode_escape')

# %%
df = pd.read_csv('online_retail_data.csv', encoding= 'unicode_escape')

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate']).dt.date

# %% [markdown]
# # Helper functions

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

# %% [markdown]
# # Cleaning

# %%
mask = (~df['CustomerID'].isna())

# %%
df = df[mask]

# %%
df = df.drop_duplicates()

# %%
df = df.loc[df['StockCode'].str.match("\d{5}")]

# %%
customer_stockcode_date = df.groupby(['CustomerID','StockCode', 'InvoiceDate'])['Quantity'].sum().reset_index()

# %%
customer_stockcode_date = customer_stockcode_date[customer_stockcode_date['Quantity']>0]
customer_stockcode_date.head()
# Out:
#    CustomerID StockCode InvoiceDate  Quantity
# 1     12347.0     16008  2011-07-04        24
# 2     12347.0     17021  2011-09-06        36
# 3     12347.0     20665  2011-07-04         6
# 4     12347.0     20719  2011-01-26        10
# 5     12347.0     20719  2011-02-08        10

# %%
df = pd.merge(left=df,
              right=customer_stockcode_date[['CustomerID','StockCode','InvoiceDate']],
              how='inner',
              on = ['CustomerID','StockCode','InvoiceDate']
             )

# %%
#Product code dict
Products = df.drop_duplicates(subset='StockCode')[['StockCode','Description']]

Products = dict(zip(df['StockCode'], df['Description']))

# %% [markdown]
# # RFM Engineering

# %%
last_day = df['InvoiceDate'].max()

# %%
df['Sale'] = df['Quantity']*df['UnitPrice']

# %%
RFM_df = df.groupby('CustomerID').agg({'Sale':'sum', 'InvoiceNo':'nunique', 'InvoiceDate':'max', 'Country':'first'}).reset_index()

# %%
RFM_df = RFM_df.rename(columns={'Sale':'Monetary_Total', 'InvoiceNo':'Frequency', 'InvoiceDate':'LastPurchase'})

# %%
RFM_df['Recency'] = (RFM_df['LastPurchase'] - last_day).dt.days

# %%
RFM_df['Monetary_Average'] = RFM_df['Monetary_Total']/RFM_df['Frequency']

# %%
bin_labels = ['1', '2', '3', '4', '5']
RFM_df['Recency Score'] = pd.qcut(RFM_df['Recency'],
                              q=5,
                              labels=bin_labels)
RFM_df['Frequency Score'] = pd.qcut(RFM_df['Frequency'],
                             q=5,
                             labels=['2', '3', '4', '5'],
                             duplicates='drop')
RFM_df['Monetary Score'] = pd.qcut(RFM_df['Monetary_Average'],
                              q=5,
                              labels=bin_labels)

RFM_df['RFM_Score'] = RFM_df['Recency Score'].astype('str') + RFM_df['Frequency Score'].astype('str') + RFM_df['Monetary Score'].astype('str')

RFM_df = RFM_df.reindex(columns=['CustomerID','Monetary_Total','Recency','Frequency','Monetary_Average','LastPurchase',
                                 'Recency Score', 'Frequency Score','Monetary Score','RFM_Score', 'Country'
                                ])
RFM_df.head()
# Out:
#    CustomerID  Monetary_Total  Recency  Frequency  Monetary_Average  \
# 0     12347.0         4310.00      -40          7        615.714286
# 1     12348.0         1437.24      -76          4        359.310000
# 2     12349.0         1457.55      -19          1       1457.550000
# 3     12350.0          294.40     -311          1        294.400000
# 4     12352.0         1265.41      -73          6        210.901667
#
#   LastPurchase Recency Score Frequency Score Monetary Score RFM_Score  Country
# 0   2011-10-31             4               5              5       455  Iceland
# 1   2011-09-25             3               4              4       344  Finland
# 2   2011-11-21             4               2              5       425    Italy
# 3   2011-02-02             1               2              3       123   Norway
# 4   2011-09-28             3               4              2       342   Norway

# %%
# RFM Clustering

# # Segmentation

# RFM_df['Tier'] = 'Tier 4'
# RFM_df.loc[RFM_df['Monetary Score'].astype(int)>=3,'Tier'] = 'Tier 3'
# RFM_df.loc[RFM_df['Frequency Score'].astype(int)>=3,'Tier'] = 'Tier 2'
# RFM_df.loc[(RFM_df['Monetary Score'].astype(int)>=3)&(RFM_df['Frequency Score'].astype(int)>=4),'Tier'] = 'Tier 1'

# fig = px.scatter(RFM_df, x= 'Recency', y='Frequency', size='Monetary_Average', color='Tier', size_max=20)
# fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0)',
#                    'paper_bgcolor': 'rgba(0, 0, 0, 0)'
#                   })
# fig.show()

# fig = px.scatter(RFM_df, x= 'Monetary_Average', y='Frequency', size='Monetary_Total', color='Tier', size_max=20)
# fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0)',
#                    'paper_bgcolor': 'rgba(0, 0, 0, 0)'
#                   })
# fig.show()

# tiers = RFM_df.drop_duplicates(subset='Tier')[['CustomerID','Tier']]
# tiers = dict(zip(RFM_df['CustomerID'], RFM_df['Tier']))

# df['Tier'] = df['CustomerID'].map(tiers)

# %% [markdown]
# # K-Means clustering

# %%
# Perform K-means algorithm
norm = MinMaxScaler()
data = pd.DataFrame(norm.fit_transform(RFM_df[['Monetary_Average', 'Frequency']]), columns=['M_Scaled', 'F_Scaled'])

# %%
km_scores = []

for k in range(2, 11):
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(data)
    km_scores.append(-km.score(data))

# %%
fig = px.line(x= range(2,11), y=km_scores)
fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0)',
                   'paper_bgcolor': 'rgba(0, 0, 0, 0)'
                  })
fig.update_xaxes(title = 'Number of Clusters')
fig.update_yaxes(title = 'Clustering Score')
fig.show()
# Out:
# <div>                            <div id="d0685880-98cb-4d23-aae8-87f80c69e8de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0685880-98cb-4d23-aae8-87f80c69e8de")) {                    Plotly.newPlot(                        "d0685880-98cb-4d23-aae8-87f80c69e8de",                        [{"hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": [2, 3, 4, 5, 6, 7, 8, 9, 10], "xaxis": "x", "y": [10.748537428924287, 8.0297074079878, 5.927261477986633, 4.287198162672509, 3.527806453811182, 2.9127388507447596, 2.3440561164281477, 1.9695076935946223, 1.666629186457635], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "paper_bgcolor": "rgba(0, 0, 0, 0)", "plot_bgcolor": "rgba(0, 0, 0, 0)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d" ...

# %%
no_of_clusters = 5
model = KMeans(n_clusters=no_of_clusters, random_state=42)
cluster = pd.DataFrame(model.fit_predict(data)).astype('category')
cluster.columns = ['Cluster']
data = data.merge(cluster, left_index=True, right_index=True)
data = pd.concat([RFM_df,data], axis=1)
fig = px.scatter(data,
                 x='M_Scaled',
                 y='F_Scaled',
                 size = 'Monetary_Total',
                 color='Cluster')
fig.update_layout({'plot_bgcolor': 'rgba(0, 0, 0, 0)',
                   'paper_bgcolor': 'rgba(0, 0, 0, 0)'
                  })
fig.show()
# Out:
# <div>                            <div id="4819dc1b-08f3-4f49-9c09-64e0e40fd5e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4819dc1b-08f3-4f49-9c09-64e0e40fd5e6")) {                    Plotly.newPlot(                        "4819dc1b-08f3-4f49-9c09-64e0e40fd5e6",                        [{"hovertemplate": "Cluster=0<br>M_Scaled=%{x}<br>F_Scaled=%{y}<br>Monetary_Total=%{marker.size}<extra></extra>", "legendgroup": "0", "marker": {"color": "#636efa", "size": [4309.999999999997, 1437.24, 294.40000000000003, 1265.41, 89.0, 459.4, 928.06, 174.89999999999998, 4737.230000000003, 552.0, 1208.1000000000001, 320.69, 150.9, 1196.04, 324.6, 622.93, 377.5000000000001, 777.2399999999997, 2427.81, 1474.8100000000006, 1628.5599999999995, 425.27000000000004, 401.90000000000003, 2780.6600000000003, 504.84, 439.65999999999997, 1582.6000000000004, 1080.48, 2682.6299999999987, 1033.65, 69.3, 195.6, 391.7, 1507.12, 2618.5500000000006, 533.3299999999999, 1142.8799999999999, 686.1, 442.41, 3226.1000000000004, 668.5799999999997, 600.3900000000001, 639.0400000000002, 683.5599999999998, 1634.3100000000002, 510.7299999999999, 699.8000000000002, 216.4, 806.14, 429.01000000000005, 155.55, 144.06, 77.4, 431.49, 365.4500000000001, 197.88, 348.57000000000005, 2339.859999999997, 1667.8799999999997, 787.4000000000001, 626.8800000000001, 937.59, 1200.7799999999997, 957.0499999999998, 682.19, 657.54, 669.38, 5885.970000000006, 545.99, 473.2, 5003.820000000002, 1910.9800000000005, 1244.6600000000003, 298.93, 4859.930000000001, 424.4000000000001, 227.20999999999998, 379.74, 1079.1500000000005, 349.7, 4047.92, 2995.870000000001, 395.4, 73.50000000000003, 1006.0599999999998, 397.8800000000001, 158.5, 814.57, 132.18000000000006, 558.2900000000001, 278.7, 1186.06, 2281.8000000000006, 1840.8899999999996, 276.84, 2346.259999999999, 545.6800000000001, 156.72000000000003, 1699.7700000000004, 3945.72, 1172.6600000000003, 330.71000000000004, 1645.4800000000002, 1500.2799999999995, 125.22, 313.83, 716.3500000000001, 363.95, 841.1800000000002, 316.7, 832.3899999999999, 1021.5000000000002, 151.8, 67.19999999999999, 168.0, 317.81999999999994, 3278.2799999999997, 599.5599999999997, 269.96000000000004, 525.7099999999999, 238.85, 3385.740000000002, 402.9000000000001, 145.92, 297.65000000000003, 519.6099999999999, 912.4200000000002, 160.54, 182.45000000000002, 1315.8299999999997, 591.45, 386.41999999999996, 379.7, 179.70999999999998, 351.3599999999999, 2241.3999999999996, 196.94, 104.0, 174.9, 574.6800000000001, 368.84999999999985, 401.59999999999997, 382.09999999999997, 3208.219999999998, 450.27, 2807.079999999998, 888.5800000000004, 2311.04, 487.06, 153.12000000000003, 613.1999999999999, 236.17999999999995, 964.8500000000001, 1747.5400000000006, 668.0400000000001, 315.59999999999997, 2093.1900000000005, 641.3000000000001, 352.9800000000002, 137.31, 2945.56, 1303.4099999999999, 162.09999999999997, 269.1, 569.1300000000001, 5954.479999999997, 4082.5300000000016, 732.4599999999999, 1030.8800000000003, 480.50000000000017, 1929.9799999999996, 511.69, 366.1, 994.5799999999999, 145.9, 905.26, 3041.6400000000003, 477.9100000000001, 1631.1800000000007, 1346.9700000000003, 3146.82, 300.05, 569.51, 242.44, 114.00000000000003, 529.98, 1008.0599999999998, 632.0500000000001, 73.68, 227.10000000000002, 3543.7799999999975, 4391.879999999999, 45.0, 460.12999999999994, 2744.0499999999997, 225.9, 574.52, 1844.6000000000006, 1091.39, 951.0200000000003, 790.81, 2073.6299999999997, 2575.0800000000004, 71.14, 1139.6100000000001, 335.00999999999993, 927.8, 711.91, 761.6699999999998, 582.1, 757.5900000000001, 725.7099999999999, 201.0, 265.54999999999995, 1740.8400000000001, 603.42, 2442.9100000000003, 1023.0200000000007, 263.36, 963.4899999999996, 830.98, 202.25000000 ...

# %%
Clusters = data.drop_duplicates(subset='Cluster')[['CustomerID','Cluster']]
Clusters = dict(zip(data['CustomerID'], data['Cluster']))

# %%
df['Cluster'] = df['CustomerID'].map(Clusters)

# %%
data.to_csv('Clustering_result.csv', index=False)

# %%
# percentage of non-UK customers
# data[data['Country']!='United Kingdom'].groupby('Cluster')['Country'].size()/data['Cluster'].value_counts()
data[data['Country']!='United Kingdom'].groupby('Cluster')['Country'].size()
# Out:
# Cluster
# 0    299
# 1     12
# 2      1
# 3     91
# 4     15
# Name: Country, dtype: int64

# %% [markdown]
# # Market Basket

# %%
data['Cluster'].value_counts()
# Out:
# 0    3737
# 3     340
# 4     226
# 1      23
# 2       7
# Name: Cluster, dtype: int64

# %%
df['Cluster'].value_counts()
# Out:
# 0    231428
# 4     83329
# 3     41148
# 2     24750
# 1     10468
# Name: Cluster, dtype: int64

# %%
data = df.groupby(['Cluster', 'InvoiceNo'])['StockCode'].count().reset_index()
data = data[data['StockCode']>1]
# data.groupby('Cluster')['InvoiceNo'].count()
data.groupby('Cluster')['InvoiceNo'].nunique()
# Out:
# Cluster
# 0    10592
# 1      210
# 2      837
# 3     1137
# 4     4370
# Name: InvoiceNo, dtype: int64

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# Sale           float64
# Tier            object
# Cluster          int64
# dtype: object

# %%
clusters = list(df['Cluster'].unique())

# %%
def MBA(df=df, min_support=0.04, min_lift=1.2, output_graph_name='MBA_graph.html', max_rule = None):
    print(f"***************************Cluster {cluster}***************************************")
    basket = (df.groupby(['InvoiceNo', 'StockCode'])['Quantity']
              .sum().unstack().reset_index().fillna(0)
              .set_index('InvoiceNo'))

    basket_sets = basket.applymap(encode_units)

    mask = basket_sets.sum(axis=1) > 1
    basket_sets = basket_sets[mask]

    frequent_itemsets = fpgrowth(
        basket_sets, min_support=min_support, use_colnames=True, max_len=2)
    rules = association_rules(
        frequent_itemsets, metric="lift", min_threshold=min_lift)
    # change product code to product name for readability
    rules['antecedents'] = rules['antecedents'].apply(lambda x: list(x)[0])
    rules['consequents'] = rules['consequents'].apply(lambda x: list(x)[0])
    rules['source'] = rules['antecedents'].map(Products)
    rules['target'] = rules['consequents'].map(Products)
    
    # write to csv
    filename = f'Cluster {cluster}.csv'
    rules.to_csv(filename)

    # prepare for graph visualisation
    rules_viz = rules.copy(deep=True)
    rules_viz['pair'] = rules_viz[['antecedents', 'consequents']].values.tolist()
    rules_viz['pair'] = rules_viz['pair'].apply(frozenset)
    rules_viz = rules_viz.drop_duplicates(subset='pair', keep='first')

    # for network graph
    rules_viz['value'] = rules_viz['lift']
    rules_viz['title'] = rules_viz['lift'].astype('str')
    if max_rule:
        rules_viz = rules_viz.sort_values(by = 'lift', ascending = False).head(max_rule)
    else:
        rules_viz = rules_viz.sort_values(by = 'lift', ascending = False)
    print(rules_viz.head())

    G = nx.from_pandas_edgelist(df=rules_viz,
                                source='source',
                                target='target',
                                edge_attr=['value','title']
                                )

    net = Network(height='700px', width='1000px', notebook=True)
    net.from_nx(G)
    net.show(output_graph_name)
    print("******************************************************************")

# %%
min_support_dict = {0: 0.03, 1:0.06, 2: 0.06, 3: 0.03, 4: 0.03}

for cluster in clusters:
    output_graph_name = f'Cluster {cluster}.html'
    MBA(df[df['Cluster'] == cluster], output_graph_name=output_graph_name,
        #         min_support=0.03,
        min_support=min_support_dict[cluster],
        min_lift=1,
        max_rule=100
        )
# Out:
# ***************************Cluster 4***************************************
#    antecedents consequents  antecedent support  consequent support   support  \
# 22       22699       22697            0.048070            0.037439  0.031431
# 2       82494L       82482            0.053848            0.052461  0.030968
# 0        22726       22727            0.062399            0.066790  0.042061
# 34       23203       23202            0.078345            0.063092  0.039057
# 8        21931       22386            0.068408            0.071643  0.031431
#
#     confidence       lift  leverage  conviction  \
# 22    0.653846  17.464150  0.029631    2.780731
# 2     0.575107  10.962508  0.028143    2.230066
# 0     0.674074  10.092452  0.037894    2.863258
# 34    0.498525   7.901531  0.034114    1.868304
# 8     0.459459   6.413165  0.026530    1.717460
#
#                               source                             target  \
# 22  ROSES REGENCY TEACUP AND SAUCER     GREEN REGENCY TEACUP AND SAUCER
# 2        WOODEN FRAME ANTIQUE WHITE   WOODEN PICTURE FRAME WHITE FINISH
# 0         ALARM CLOCK BAKELIKE GREEN          ALARM CLOCK BAKELIKE RED
# 34          JUMBO BAG VINTAGE DOILY              JUMBO BAG VINTAGE LEAF
# 8             JUMBO STORAGE BAG SUKI            JUMBO BAG PINK POLKADOT
#
#                pair      value               title
# 22   (22699, 22697)  17.464150  17.464150047483383
# 2   (82494L, 82482)  10.962508   10.96250779905844
# 0    (22726, 22727)  10.092452  10.092451621171344
# 34   (23203, 23202)   7.901531   7.901531113920495
# 8    (21931, 22386)   6.413165   6.413164777680908
# ******************************************************************
# ***************************Cluster 0***************************************
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, source, target, pair, value, title]
# Index: []
# ******************************************************************
# ***************************Cluster 2***************************************
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, source, target, pair, value, title]
# Index: []
# ******************************************************************
# ***************************Cluster 3***************************************
#     antecedents consequents  antecedent support  consequent support   support  \
# 18        21086       21094            0.034636            0.036412  0.031972
# 74       47590A      47590B            0.039076            0.037300  0.031083
# 340       23172       23171            0.041741            0.046181  0.039964
# 16        22962       22963            0.043517            0.035524  0.030195
# 306       23254       23256            0.036412            0.044405  0.031083
#
#      confidence       lift  leverage  conviction  \
# 18     0.923077  25.350844  0.030710   12.526643
# 74     0.795455  21.325758  0.029626    4.706532
# 340    0.957447  20.732406  0.038037   22.414742
# 16     0.693878  19.532653  0.028649    3.150622
# 306    0.853659  19.224390  0.029467    6.529899
#
#                             source                         target  \
# 18     SET/6 RED SPOTTY PAPER CUPS  SET/6 RED SPOTTY PAPER PLATES
# 74     BLUE HAPPY BIRTHDAY BUNTING    PINK HAPPY BIRTHDAY BUNTING
# 340         REGENCY TEA PLATE PINK       REGENCY TEA PLATE GREEN
# 16           JAM JAR WITH PINK LID         JAM JAR WITH GREEN LID
# 306  CHILDRENS CUTLERY DOLLY GIRL     CHILDRENS CUTLERY SPACEBOY
#
#                  pair      value               title
# 18     (21086, 21094)  25.350844  25.350844277673545
# 74   (47590A, 47590B)  21.325758  21.325757575757578
# 340    (23171, 23172)  20.732406   20.73240589198036
# 16     (22962, 22963)  19.532653   19.53265306122449
# 306    (23254, 23256)  19.224390  19.224390243902437
# ******************************************************************
# ***************************Cluster 1***************************************
#     antecedents consequents  antecedent support  consequent support   support  \
# 870       21494      84596B            0.061905            0.061905  0.061905
# 814       22107       22422            0.061905            0.061905  0.061905
# 800       22107      85049H            0.061905            0.061905  0.061905
# 802       22107       23265            0.061905            0.061905  0.061905
# 698       21985       23221            0.061905            0.061905  0.061905
#
#      confidence       lift  leverage  conviction  \
# 870         1.0  16.153846  0.058073         inf
# 814         1.0  16.153846  0.058073         inf
# 800         1.0  16.153846  0.058073         inf
# 802         1.0  16.153846  0.058073         inf
# 698         1.0  16.153846  0.058073         inf
#
#                                 source                              target  \
# 870     ROTATING LEAVES T-LIGHT HOLDER  SMALL DOLLY MIX DESIGN ORANGE BOWL
# 814                 PIZZA PLATE IN BOX                 TOOTHPASTE TUBE PEN
# 800                 PIZZA PLATE IN BOX                URBAN BLACK RIBBONS
# 802                 PIZZA PLATE IN BOX    SET OF 3 WOODEN TREE DECORATIONS
# 698  PACK OF 12 HEARTS DESIGN TISSUES     REINDEER HEART DECORATION SILVER
#
#                 pair      value               title
# 870  (21494, 84596B)  16.153846  16.153846153846153
# 814   (22107, 22422)  16.153846  16.153846153846153
# 800  (22107, 85049H)  16.153846  16.153846153846153
# 802   (22107, 23265)  16.153846  16.153846153846153
# 698   (23221, 21985)  16.153846  16.153846153846153
# ******************************************************************

# %%
min_support_dict = {0: 0.02, 1:0.04, 2: 0.04, 3: 0.02, 4: 0.02}

for cluster in clusters:
    output_graph_name = f'Cluster {cluster}.html'
    MBA(df[df['Cluster'] == cluster], output_graph_name=output_graph_name,
        #         min_support=0.03,
        min_support=min_support_dict[cluster],
        min_lift=1,
        max_rule=100
        )
# Out:
# ***************************Cluster 4***************************************
#     antecedents consequents  antecedent support  consequent support   support  \
# 160       22698       22697            0.033511            0.037439  0.026346
# 222       23301       23300            0.042755            0.036515  0.028426
# 108       22699       22697            0.048070            0.037439  0.031431
# 162       22698       22699            0.033511            0.048070  0.027271
# 60        22086       22910            0.040675            0.032355  0.020106
#
#      confidence       lift  leverage  conviction  \
# 160    0.786207  20.999489  0.025092    4.502300
# 222    0.664865  18.208040  0.026865    2.874915
# 108    0.653846  17.464150  0.029631    2.780731
# 162    0.813793  16.929244  0.025660    5.112215
# 60     0.494318  15.277963  0.018790    1.913545
#
#                                 source                              target  \
# 160     PINK REGENCY TEACUP AND SAUCER     GREEN REGENCY TEACUP AND SAUCER
# 222  GARDENERS KNEELING PAD KEEP CALM   GARDENERS KNEELING PAD CUP OF TEA
# 108   ROSES REGENCY TEACUP AND SAUCER      GREEN REGENCY TEACUP AND SAUCER
# 162     PINK REGENCY TEACUP AND SAUCER    ROSES REGENCY TEACUP AND SAUCER
# 60     PAPER CHAIN KIT 50'S CHRISTMAS    PAPER CHAIN KIT VINTAGE CHRISTMAS
#
#                pair      value               title
# 160  (22698, 22697)  20.999489  20.999489144316733
# 222  (23301, 23300)  18.208040  18.208039685254874
# 108  (22699, 22697)  17.464150  17.464150047483383
# 162  (22698, 22699)  16.929244  16.929244031830237
# 60   (22086, 22910)  15.277963  15.277962662337663
# ******************************************************************
# ***************************Cluster 0***************************************
#    antecedents consequents  antecedent support  consequent support   support  \
# 44       22698       22697            0.025852            0.033239  0.021496
# 42       22577       22578            0.030871            0.028883  0.021023
# 40       22699       22697            0.036458            0.033239  0.024148
# 50       23301       23300            0.042803            0.035038  0.025000
# 0        22726       22727            0.036364            0.042045  0.024337
#
#     confidence       lift  leverage  conviction  \
# 44    0.831502  25.016123  0.020637    5.737519
# 42    0.680982  23.577592  0.020131    3.044080
# 40    0.662338  19.926740  0.022936    2.863101
# 50    0.584071  16.669696  0.023500    2.320015
# 0     0.669271  15.917793  0.022808    2.896492
#
#                                  source                              target  \
# 44       PINK REGENCY TEACUP AND SAUCER     GREEN REGENCY TEACUP AND SAUCER
# 42  WOODEN HEART CHRISTMAS SCANDINAVIAN  WOODEN STAR CHRISTMAS SCANDINAVIAN
# 40     ROSES REGENCY TEACUP AND SAUCER      GREEN REGENCY TEACUP AND SAUCER
# 50    GARDENERS KNEELING PAD KEEP CALM   GARDENERS KNEELING PAD CUP OF TEA
# 0            ALARM CLOCK BAKELIKE GREEN           ALARM CLOCK BAKELIKE RED
#
#               pair      value               title
# 44  (22698, 22697)  25.016123   25.01612347766194
# 42  (22577, 22578)  23.577592  23.577592275973046
# 40  (22699, 22697)  19.926740  19.926739926739923
# 50  (23301, 23300)  16.669696  16.669696244917485
# 0   (22726, 22727)  15.917793  15.917792792792794
# ******************************************************************
# ***************************Cluster 2***************************************
#   antecedents consequents  antecedent support  consequent support   support  \
# 0       22699       22697            0.054479             0.05569  0.046005
#
#    confidence       lift  leverage  conviction  \
# 0    0.844444  15.163285  0.042971    6.070564
#
#                              source                           target  \
# 0  ROSES REGENCY TEACUP AND SAUCER   GREEN REGENCY TEACUP AND SAUCER
#
#              pair      value              title
# 0  (22699, 22697)  15.163285  15.16328502415459
# ******************************************************************
# ***************************Cluster 3***************************************
#      antecedents consequents  antecedent support  consequent support  \
# 1216       23289       23291            0.025755            0.026643
# 1204       23285       23286            0.026643            0.028419
# 1206       23286       23287            0.028419            0.025755
# 1208       23285       23287            0.026643            0.025755
# 1218       23289       23290            0.025755            0.031083
#
#        support  confidence       lift  leverage  conviction  \
# 1216  0.024867    0.965517  36.239080  0.024181   28.227353
# 1204  0.025755    0.966667  34.014583  0.024998   29.147425
# 1206  0.023091    0.812500  31.547414  0.022359    5.195974
# 1208  0.021314    0.800000  31.062069  0.020628    4.871226
# 1218  0.024867    0.965517  31.062069  0.024066   28.098579
#
#                          source                    target            pair  \
# 1216  DOLLY GIRL CHILDRENS BOWL  DOLLY GIRL CHILDRENS CUP  (23289, 23291)
# 1204   PINK VINTAGE SPOT BEAKER  BLUE VINTAGE SPOT BEAKER  (23285, 23286)
# 1206   BLUE VINTAGE SPOT BEAKER   RED VINTAGE SPOT BEAKER  (23286, 23287)
# 1208   PINK VINTAGE SPOT BEAKER   RED VINTAGE SPOT BEAKER  (23285, 23287)
# 1218  DOLLY GIRL CHILDRENS BOWL   SPACEBOY CHILDRENS BOWL  (23289, 23290)
#
#           value               title
# 1216  36.239080   36.23908045977012
# 1204  34.014583  34.014583333333334
# 1206  31.547414   31.54741379310345
# 1208  31.062069  31.062068965517245
# 1218  31.062069   31.06206896551724
# ******************************************************************
# ***************************Cluster 1***************************************
#       antecedents consequents  antecedent support  consequent support  \
# 8584        23285       23288            0.042857            0.042857
# 8588        23285       23286            0.042857            0.042857
# 8586        23286       23288            0.042857            0.042857
# 24916       22565       22891            0.047619            0.047619
# 26634       16238       22124            0.047619            0.042857
#
#         support  confidence       lift  leverage  conviction  \
# 8584   0.042857         1.0  23.333333  0.041020         inf
# 8588   0.042857         1.0  23.333333  0.041020         inf
# 8586   0.042857         1.0  23.333333  0.041020         inf
# 24916  0.047619         1.0  21.000000  0.045351         inf
# 26634  0.042857         0.9  21.000000  0.040816    9.571429
#
#                                     source  \
# 8584              PINK VINTAGE SPOT BEAKER
# 8588              PINK VINTAGE SPOT BEAKER
# 8586              BLUE VINTAGE SPOT BEAKER
# 24916  FELTCRAFT HAIRBANDS PINK AND WHITE
# 26634            PARTY TIME PENCIL ERASERS
#
#                                    target            pair      value  \
# 8584            GREEN VINTAGE SPOT BEAKER  (23285, 23288)  23.333333
# 8588             BLUE VINTAGE SPOT BEAKER  (23285, 23286)  23.333333
# 8586            GREEN VINTAGE SPOT BEAKER  (23286, 23288)  23.333333
# 24916                TEA FOR ONE POLKADOT  (22565, 22891)  21.000000
# 26634  SET OF 2 TEA TOWELS PING MICROWAVE  (16238, 22124)  21.000000
#
#                     title
# 8584   23.333333333333332
# 8588   23.333333333333332
# 8586   23.333333333333332
# 24916                21.0
# 26634                21.0
# ******************************************************************
